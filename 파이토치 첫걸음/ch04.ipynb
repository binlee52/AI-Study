# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
from tqdm import tqdm

num_data = 1000
num_epoch = 10000
noise = init.normal_(torch.FloatTensor(num_data, 1), std=1)
x = init.uniform_(torch.Tensor(num_data, 1), -15, 15)
y = (x**2) + 3
y_noise = y + noise

model = nn.Sequential(
    nn.Linear(1, 6),
    nn.ReLU(),
    nn.Linear(6, 10),
    nn.ReLU(),
    nn.Linear(10, 6),
    nn.ReLU(),
    nn.Linear(6, 1),
)

loss_func = nn.L1Loss()
optimizer = optim.SGD(model.parameters(), lr=0.0002)

loss_array = []

# %%
loss_array = []
for i in tqdm(range(num_epoch)):
    optimizer.zero_grad()
    output = model(x)
    loss = loss_func(output, y_noise)
    loss.backward()
    optimizer.step()
    
    if i % 100 == 0:
        print(loss.data)
    loss_array.append(loss)
# Out:
#   4%|▍         | 391/10000 [00:00<00:05, 1815.84it/s]
# tensor(76.6150)
# tensor(76.4557)
# tensor(76.2665)
# tensor(76.0343)
#   8%|▊         | 820/10000 [00:00<00:04, 1971.38it/s]
# tensor(75.7395)
# tensor(75.3523)
# tensor(74.8242)
# tensor(74.0712)
# tensor(72.9376)
#  12%|█▏        | 1214/10000 [00:00<00:04, 1931.96it/s]
# tensor(71.1058)
# tensor(67.8444)
# tensor(61.3082)
# tensor(51.4877)
#  16%|█▌        | 1612/10000 [00:00<00:04, 1965.74it/s]
# tensor(46.5152)
# tensor(45.9765)
# tensor(45.5741)
# tensor(45.0664)
# tensor(44.4081)
#  20%|██        | 2032/10000 [00:01<00:03, 2031.81it/s]
# tensor(43.4767)
# tensor(42.0912)
# tensor(39.7478)
# tensor(34.8662)
# tensor(27.7616)
#  27%|██▋       | 2659/10000 [00:01<00:03, 2053.79it/s]
# tensor(22.0642)
# tensor(20.7775)
# tensor(20.4947)
# tensor(20.2686)
# tensor(20.0249)
#  31%|███       | 3088/10000 [00:01<00:03, 2100.84it/s]
# tensor(19.8255)
# tensor(19.6237)
# tensor(19.4225)
# tensor(19.2234)
# tensor(19.0227)
#  37%|███▋      | 3725/10000 [00:01<00:03, 2071.20it/s]
# tensor(18.8193)
# tensor(18.6178)
# tensor(18.4139)
# tensor(18.2074)
# tensor(17.9942)
#  42%|████▏     | 4160/10000 [00:02<00:02, 2122.02it/s]
# tensor(17.7699)
# tensor(17.5395)
# tensor(17.2974)
# tensor(17.0468)
# tensor(16.7905)
#  46%|████▌     | 4597/10000 [00:02<00:02, 2146.97it/s]
# tensor(16.5176)
# tensor(16.2258)
# tensor(15.9209)
# tensor(15.5981)
# tensor(15.2615)
#  50%|█████     | 5028/10000 [00:02<00:02, 2051.17it/s]
# tensor(14.9166)
# tensor(14.5683)
# tensor(14.2221)
# tensor(13.8635)
# tensor(13.4987)
#  57%|█████▋    | 5693/10000 [00:02<00:01, 2153.83it/s]
# tensor(13.1330)
# tensor(12.7507)
# tensor(12.3467)
# tensor(11.9317)
# tensor(11.5156)
#  61%|██████▏   | 6132/10000 [00:02<00:01, 2173.75it/s]
# tensor(11.0800)
# tensor(10.6302)
# tensor(10.1557)
# tensor(9.6763)
# tensor(9.2056)
#  66%|██████▌   | 6577/10000 [00:03<00:01, 2197.81it/s]
# tensor(8.7437)
# tensor(8.2791)
# tensor(7.7989)
# tensor(7.3328)
# tensor(6.8805)
#  70%|███████   | 7019/10000 [00:03<00:01, 2194.49it/s]
# tensor(6.4485)
# tensor(6.0379)
# tensor(5.6532)
# tensor(5.2818)
# tensor(4.9228)
#  77%|███████▋  | 7676/10000 [00:03<00:01, 2170.76it/s]
# tensor(4.5947)
# tensor(4.2916)
# tensor(3.9986)
# tensor(3.7428)
# tensor(3.5104)
#  81%|████████  | 8112/10000 [00:03<00:00, 2168.67it/s]
# tensor(3.4921)
# tensor(3.3769)
# tensor(3.5942)
# tensor(3.5463)
# tensor(3.5680)
#  85%|████████▌ | 8545/10000 [00:04<00:00, 2150.81it/s]
# tensor(3.5151)
# tensor(3.4484)
# tensor(3.3803)
# tensor(3.2783)
# tensor(3.2343)
#  92%|█████████▏| 9190/10000 [00:04<00:00, 2133.69it/s]
# tensor(3.1585)
# tensor(3.0879)
# tensor(3.0263)
# tensor(3.0050)
# tensor(3.0089)
#  96%|█████████▌| 9618/10000 [00:04<00:00, 2120.39it/s]
# tensor(3.0416)
# tensor(2.9948)
# tensor(2.9989)
# tensor(3.0207)
# tensor(3.0579)
# 100%|██████████| 10000/10000 [00:04<00:00, 2107.92it/s]
# tensor(3.0433)
# tensor(3.0361)

# %%
import matplotlib.pyplot as plt

plt.plot(loss_array)
plt.show()
